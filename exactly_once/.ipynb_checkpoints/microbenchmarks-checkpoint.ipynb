# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 18})

# %%
x = [1,2,3,4,5,6]
y = [1558.5,1561.8,1467.8,1444.0,1379.3,1351.8]
y2 = [2102.1,2787.9,3007.1,2570.7,2834.4,2658.3]
y3 = [2044.6,2559.8,2062.3,2291.8,2284.4,2257.5]
y4 = [2005.0,1882.7,2031.8,1638.6,1886.1,2123.6]
plt.figure(figsize=(10,7))
plt.plot(x, y, linestyle='--', marker='o', color='b', label='Exactly once')
plt.plot(x, y2, linestyle='--', marker='o', color='r', label='No guarantees')
plt.plot(x, y3, linestyle='--', marker='o', color='g', label='Checkpoints (freq=1000)')
plt.plot(x, y4, linestyle='--', marker='o', color='orange', label='Checkpoints (freq=100)')
plt.xlabel('Number of clients')
plt.ylabel('Throughput (reqs/s)')
plt.title('Throughput benchmark')
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [1789.5,1801.1,1780.8,1868.3,1639.8,1661.0]
y2 = [2036.4,2616.2,2646.8,2535.7,2313.4,2325.9]
y3 = [2026.9,1854.3,2047.2,2060.0,1812.6,2069.0]
# y4 = [2005.0,1882.7,2031.8,1638.6,1886.1,2123.6]
plt.figure(figsize=(10,7))
plt.plot(x, y, linestyle='--', marker='o', color='b', label='Exactly once')
plt.plot(x, y2, linestyle='--', marker='o', color='r', label='No guarantees')
plt.plot(x, y3, linestyle='--', marker='o', color='g', label='Checkpoints (freq=1000)')
# plt.plot(x, y4, linestyle='--', marker='o', color='orange', label='Checkpoints (freq=100)')
plt.xlabel('Number of clients')
plt.ylabel('Throughput (reqs/s)')
plt.title('Throughput benchmark')
plt.legend()
plt.show()

# %%
import numpy as np
import os

DIR = "/Users/accheng/Documents/ray_notebooks/exactly_once"


NG = []
CK = []
EO = []
NGnF = []
CKnF = []
EOnF = []

def load(filename):
    results = []
    num_over_1000 = 0
    with open(filename, 'r') as f:
        for line in f.readlines():
            line = line.strip()
            latency = float(line)
            results.append(latency)
    print(filename)
    print("\tlength", len(results))
    print("\tmean", np.mean(results))
    print("\tp50:", np.percentile(results, 50))
    print("\tp90:", np.percentile(results, 90))
    print("\tp99:", np.percentile(results, 99))
    print("\tp100:", np.max(results))
    print("\tstd:", np.std(results))

    return results

for f in os.listdir(DIR):
    if not f.endswith('txt'):
        continue
    print(f)
    results = load(os.path.join(DIR, f))
    if "EOF_" in f:
        EO = results
        print("EO")
    elif "CF_" in f:
        CK = results
        print("CF")
    elif "NF_" in f:
        NG = results
        print("NF")
    elif "EOnF" in f:
        EOnF = results
        print("EOnF")
    elif "CFnF" in f:
        CKnF = results
        print("CFnF")
    elif "NFnF" in f:
        NGnF = results
        print("NFnF")
# Out:
# NFnF_20K_1K_3.txt
# /Users/accheng/Documents/ray_notebooks/exactly_once/NFnF_20K_1K_3.txt
# 	length 8000
# 	mean 4.3909885786473755
# 	p50: 4.3018646240234375
# 	p90: 8.244084596633911
# 	p99: 9.138084664344788
# 	p100: 9.240188837051392
# 	std: 2.714104261983684
# NFnF
# CF_20K_1K_3.txt
# /Users/accheng/Documents/ray_notebooks/exactly_once/CF_20K_1K_3.txt
# 	length 8000
# 	mean 9.615092910140753
# 	p50: 11.079177379608154
# 	p90: 15.638363695144655
# 	p99: 16.600306243896487
# 	p100: 16.707642078399658
# 	std: 5.397201843046295
# CF
# NF_20K_1K_3.txt
# /Users/accheng/Documents/ray_notebooks/exactly_once/NF_20K_1K_3.txt
# 	length 8000
# 	mean 8.506597342342138
# 	p50: 9.793012499809265
# 	p90: 13.776464581489563
# 	p99: 14.606888833045959
# 	p100: 14.705517768859863
# 	std: 4.771106750701024
# NF
# EOnF_20K_1K_3.txt
# /Users/accheng/Documents/ray_notebooks/exactly_once/EOnF_20K_1K_3.txt
# 	length 8000
# 	mean 5.37653936073184
# 	p50: 5.264210224151611
# 	p90: 10.044152832031251
# 	p99: 11.096449632644655
# 	p100: 11.213163137435913
# 	std: 3.320400403765919
# EOnF
# EOF_20K_1K_3.txt
# /Users/accheng/Documents/ray_notebooks/exactly_once/EOF_20K_1K_3.txt
# 	length 8000
# 	mean 9.663165466547012
# 	p50: 11.105240941047668
# 	p90: 15.896805000305175
# 	p99: 16.96913303613663
# 	p100: 17.091700315475464
# 	std: 5.507727426457073
# EO
# CFnF_20K_1K_3.txt
# /Users/accheng/Documents/ray_notebooks/exactly_once/CFnF_20K_1K_3.txt
# 	length 8000
# 	mean 4.8879237704575065
# 	p50: 4.8143908977508545
# 	p90: 9.076742434501648
# 	p99: 10.03083479642868
# 	p100: 10.139580965042114
# 	std: 2.9887772628837994
# CFnF

# %%
x1nF = [i for i in range(len(EOnF))]
x2nF = [i for i in range(len(CKnF))]
x3nF = [i for i in range(len(NGnF))]
x1 = [i for i in range(len(EO))]
x2 = [i for i in range(len(CK))]
x3 = [i for i in range(len(NG))]
plt.figure(figsize=(10,7))
# plt.plot(x1nF, EOnF, linestyle='--', marker='.', color='orange', label='Exactly once nF')
# plt.plot(x2nF, CKnF, linestyle='--', marker='.', color='m', label='Checkpoints (freq=1000) nF')
# plt.plot(x3nF, NGnF, linestyle='--', marker='.', color='cyan', label='No guarantees nF')
plt.plot(x3, NG, linestyle='--', marker='.', color='r', label='No guarantees')
plt.plot(x1, EO, linestyle='--', marker='.', color='b', label='Exactly once')
plt.plot(x2, CK, linestyle='--', marker='.', color='g', label='Checkpoints (freq=1000)')

plt.xlabel('Requests')
plt.ylabel('Latency (s)')
plt.title('Request Time -- Long Compute')
plt.legend()
plt.show()

# %%
Backup3 = CK

# %%
Backup2 = EO

# %%
Backup = EO

# %%
import numpy as np
import os

DIR = "/Users/accheng/Documents/ray_notebooks/exactly_once"


NGnF = []
CKnF = []
EOnF = []

def load(filename):
    results = []
    num_over_1000 = 0
    with open(filename, 'r') as f:
        for line in f.readlines():
            line = line.strip()
            latency = float(line)
            results.append(latency)
    print(filename)
    print("\tlength", len(results))
    print("\tmean", np.mean(results))
    print("\tp50:", np.percentile(results, 50))
    print("\tp90:", np.percentile(results, 90))
    print("\tp99:", np.percentile(results, 99))
    print("\tp100:", np.max(results))
    print("\tstd:", np.std(results))

    return results

for f in os.listdir(DIR):
    if not f.endswith('txt'):
        continue
    print(f)
    results = load(os.path.join(DIR, f))
    if "EOnF" in f:
        EOnF = results
        print("EO")
    elif "CFnF" in f:
        CKnF = results
        print("CF")
    elif "NFnF" in f:
        NGnF = results
        print("NF")
